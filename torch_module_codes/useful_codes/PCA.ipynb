# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from sklearn import datasets
from sklearn.decomposition import PCA
from sklearn.preprocessing import StandardScaler

# %%
#dataset load
iris=datasets.load_iris()
X=iris.data
y=iris.target

# %%
#lets scale
scaler=StandardScaler()
scaler.fit(X)
X=scaler.transform(X)

# %%
pca=PCA(n_components=3)

# %%
new_X=pca.fit_transform(X)

# %%
fig,axes=plt.subplots(1,2)
axes[0].scatter(X[:,0],X[:,1],c=y)
axes[0].set_title('before pca')

axes[1].scatter(new_X[:,0],new_X[:,1],c=y)
axes[1].set_title('after pca')
# Out:
# Text(0.5, 1.0, 'after pca')

# %%
print(pca.explained_variance_ratio_)
# Out:
# [0.72962445 0.22850762 0.03668922]

# %%
#LETS CHECK THE EIGEN VALUES
np.cov(new_X.T)
# Out:
# array([[ 2.93808505e+00, -1.90749728e-16,  4.17265029e-17],
#        [-1.90749728e-16,  9.20164904e-01, -1.70165895e-16],
#        [ 4.17265029e-17, -1.70165895e-16,  1.47741821e-01]])

# %%
pca.explained_variance_
# Out:
# array([2.93808505, 0.9201649 , 0.14774182])
