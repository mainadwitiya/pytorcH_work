# %% [markdown]
# ### A very simple notebook for various activation functions.
#
# I will keep adding more functions in a few days and also the code for pytorch implementation.

# %%
import numpy as np

array1 = np.array([[1,7,3],[4,1,6]])

# %% [markdown]
# ### Sigmoid Activation
# Value ranges from 0 to 1
# ![1_-aDRUctmGhwjXVF0LS8Zqw.jpeg](attachment:1_-aDRUctmGhwjXVF0LS8Zqw.jpeg)

# %%
def sigmoid_fuunc(X):
    return 1/(1+np.exp(-X))
result =sigmoid_fuunc(array1)
print(f'Sigmoid Output :: {result}')
# Out:
# Sigmoid Output :: [[0.73105858 0.99908895 0.95257413]
#  [0.98201379 0.73105858 0.99752738]]

# %% [markdown]
# ### ReLU Activation
# Vv straigh forward
# ![1_ugxPV_0OL-LBN95LHZofUQ.jpeg](attachment:1_ugxPV_0OL-LBN95LHZofUQ.jpeg)

# %%
def relu_func(X):
    return np.maximum(0,X)
result =relu_func(array1)
print(f'ReLu Output :: {result}')
# Out:
# ReLu Output :: [[1 7 3]
#  [4 1 6]]

# %% [markdown]
# ### Softmax Activation
# The Softmax function produces an output which is a range of values between 0 and 1
# Note- Softmax are used because Linear layers digest the vectors but doesn't add to 1.
# ![1_48FpDngytN34rvVlnw0ojA.jpeg](attachment:1_48FpDngytN34rvVlnw0ojA.jpeg)

# %%
def softmax(X):
    return np.exp(X)/np.sum(np.exp(X))
result =softmax(array1)
print(f'Softmax Output :: {result}')
# Out:
# Softmax Output :: [[0.00172023 0.69399159 0.0127109 ]
#  [0.03455181 0.00172023 0.25530524]]

# %% [markdown]
# ### Tanh Activation
# The function can have values ranging from (-1, 1), making the output normalized with respect to the input. Due to the above properties, tanh is a very good choice for backpropagation.
# ![softmax_function.svg](attachment:softmax_function.svg)

# %%
def tanh(X):
    return np.tanh(X)
result =tanh(array1)
print(f'Tanh output :: {result}')
# Out:
# Tanh output :: [[0.76159416 0.99999834 0.99505475]
#  [0.9993293  0.76159416 0.99998771]]
